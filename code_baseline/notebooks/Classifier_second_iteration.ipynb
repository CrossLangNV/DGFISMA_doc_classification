# %%
import glob
import json
import base64
import os

DATA_DIR= "/notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/EURLEX/"
files=glob.glob( os.path.join( DATA_DIR , "*.jsonl" )  )

# %%
#good EURLEX example
print( files[13518] )
#http://data.europa.eu/eli/reg_del/2017/2361/oj
# Out:
# /notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/EURLEX/doc_bf4ef384-bd7a-51c8-8f7d-d2f61865d767.jsonl

# %%
# !scp -r /notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/EURLEX/doc_27540107-b189-54b8-83a7-d20c6524b424.jsonl .

# %%
#!scp -r /notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/EURLEX/doc_bf4ef384-bd7a-51c8-8f7d-d2f61865d767.jsonl .

# %%
#122163
#good
#i= 13518
good_file=''

for i,file in enumerate(files):
    if i%1000==0:
        print(i)
    jsonl=open( file ).read().rstrip("\n").split( "\n" )
    json_data=json.loads( jsonl[0])
    if json_data['celex']== ['32013R0575']:
        print( file )
        good_file=file
    #json_accepted=json.loads( jsonl[1])
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# /notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/EURLEX/doc_27540107-b189-54b8-83a7-d20c6524b424.jsonl
# 76000
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-20-564b8dccc210> in <module>
#       7     if i%1000==0:
#       8         print(i)
# ----> 9     jsonl=open( file ).read().rstrip("\n").split( "\n" )
# ...

# %%
files[13518]
# Out:
# '/notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/EURLEX/doc_bf4ef384-bd7a-51c8-8f7d-d2f61865d767.jsonl'

# %%
json_accepted
# Out:
# {'classifier_status': 'Rejected', 'classifier_score': 0.01114660000357808}

# %%
json_accepted
# Out:
# {'classifier_status': 'Accepted', 'classifier_score': 0.9281072431033988}

# %%
#with open( os.path.join( "/notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/example.html" ), "w"   ) as f:
#    f.write( json_data['content_html'][0] )

# %%
len(files)
# Out:
# 123579

# %%
files_accepted=[]

i=0
for j, file in enumerate(files):
    jsonl=open( file ).read().rstrip("\n").split( "\n" )
    if j%1000==0:
        print(j)
    if len( jsonl )==2:
        #json_content=json.loads( jsonl[0])
        json_accepted=json.loads( jsonl[1])
        if json_accepted[ 'classifier_status' ]=='Accepted':
            print(j)
            files_accepted.append( file )
# Out:
# 0
# 127
# 132
# 158
# 163
# 234
# 240
# 281
# 356
# 373
# 425
# 501
# 570
# 582
# 600
# 631
# 734
# 790
# 803
# 816
# 931
# 955
# 972
# 975
# 1000
# 1063
# 1094
# 1095
# 1100
# 1124
# 1225
# 1242
# 1265
# 1313
# 1339
# 1378
# 1401
# 1426
# 1488
# 1576
# 1590
# 1672
# 1866
# 1881
# 2000
# 2092
# 2144
# 2158
# 2186
# 2203
# 2319
# 2498
# 2523
# 2558
# 2575
# 2637
# 2755
# 2857
# 2858
# 2885
# 3000
# 3005
# 3389
# 3394
# 3405
# 3421
# 3578
# 3604
# 3685
# 3890
# 3928
# 3940
# 4000
# 4061
# 4093
# 4115
# 4140
# 4173
# 4193
# 4454
# 4459
# 4496
# 4554
# 4601
# 4610
# 4637
# 4644
# 4684
# 4764
# 4796
# 4836
# 5000
# 5008
# 5055
# 5057
# 5154
# 5173
# 5210
# 5247
# 5326
# 5347
# 5392
# 5427
# 5455
# 5515
# 5527
# 5657
# 5662
# 5692
# 5778
# 5794
# 5813
# 5867
# 5889
# 5899
# 5915
# 5922
# 5969
# 6000
# 6047
# 6059
# 6069
# 6132
# 6170
# 6194
# 6210
# 6220
# 6221
# 6256
# 6282
# 6315
# 6364
# 6457
# 6613
# 6631
# 6663
# 6778
# 6837
# 6969
# 6987
# 6996
# 7000
# 7010
# 7050
# 7098
# 7202
# ...

# %%
len( files_accepted )
# Out:
# 2548

# %%
i=107

jsonl=open( files_accepted[i] ).read().rstrip("\n").split( "\n" )
json_accepted=json.loads( jsonl[1] )
json_content=json.loads( jsonl[0] )
json_content
# Out:
# {'celex': ['32018R1795'],
#  'title': ['Commission Implementing Regulation (EU) 2018/1795 of 20 November 2018 laying down procedure and criteria for the application of the economic equilibrium test pursuant to Article 11 of Directive 2012/34/EU of the European Parliament and of the Council (Text with EEA relevance.)'],
#  'status': ['In force'],
#  'ELI': ['http://data.europa.eu/eli/reg_impl/2018/1795/oj'],
#  'various': ['OJ L 294, 21.11.2018, p. 5–14 (BG, ES, CS, DA, DE, ET, EL, EN, FR, HR, IT, LV, LT, HU, MT, NL, PL, PT, RO, SK, SL, FI, SV)'],
#  'date': ['2018-11-20T00:00:00Z'],
#  'dates_type': ['date of document',
#   'date of effect',
#   'date of effect',
#   'date of end of validity'],
#  'dates_info': ['Date of adoption',
#   'Entry into force                    Date pub. +20 See Art 16',
#   'Application                    See Art 16',
#   'n/a'],
#  'classifications_label': ['provision of services',
#   'rail network',
#   'tendering',
#   'EU competition policy',
# ...

# %%
import os
with open( "/notebook/nas-trainings/arne/DGFISMA/DATA/doc_classifier/DATA_DUMP_ACCEPTED_EURLEX_13_08/list_of_all_accepted" , "w"  ) as f:
    for path in files_accepted:
        f.write( f"{ os.path.basename(  path )  }\n" )

# %%
import os

# %%
jsonl=open( files[0] ).read().rstrip("\n").split( "\n" )
jsonl[1]
# Out:
# '{"classifier_status": "Rejected", "classifier_score": 0.01114660000357808}'

# %%
jsonl=open( files[190] ).read().rstrip("\n").split( "\n" )

# %%
['classifier_status']
# Out:
#   File "<ipython-input-26-a3d9f8c29535>", line 1
#     ]['classifier_status']
#     ^
# SyntaxError: invalid syntax
