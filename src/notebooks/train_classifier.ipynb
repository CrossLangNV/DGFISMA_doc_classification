# %%
import sys
sys.path.append( "/notebook/nas-trainings/arne/DGFISMA_doc_classification/src/classifier")
from train import train

import configparser

CONFIG = configparser.ConfigParser()
CONFIG.read( "/notebook/nas-trainings/arne/DGFISMA_doc_classification/src/classifier/train.config" )

train( CONFIG  )
# Out:
# Removing punctuation and numbers
# 11956 documents - 260.550MB (training set)
# 2 categories
#
# Using Tfidf Vectorizer.
# Using balanced class weights.
# Extracting features via sklearn.feature_selection. SelectKbest using LinearSVC.
# Selected features are:
#
# accession
# accordingly
# accounting
# achieved
# acp
# adjusting
# adjustment
# administrative
# advantage
# af
# agents
# agreement
# agus
# aid
# air
# amend
# amending
# andorra
# anexo
# apply
# applying
# approved
# arearelated
# areas
# arising
# arrangement
# aspects
# association
# associations
# auditors
# authentic
# authorised
# avoidance
# azerbaijan
# ba
# bank
# bce
# beneficiary
# benefits
# bilateral
# bodies
# budget
# budgetary
# bureaux
# byť
# calculating
# calculation
# calendar
# calls
# cancellation
# candidates
# candied
# carried
# carry
# ce
# cee
# cfsp
# chairman
# charges
# checks
# coal
# cofinancing
# cohesion
# coins
# commercial
# commun
# communication
# communitys
# companies
# company
# compatible
# competent
# competition
# competitors
# compilation
# compm
# comune
# concerning
# concerted
# conditions
# consequently
# considerando
# consumer
# content
# context
# contracting
# contraventions
# contributions
# conversion
# cooperation
# coordination
# correct
# correction
# corrigendum
# cosmetology
# countries
# cpa
# credit
# currencies
# currency
# customers
# customs
# da
# dans
# dated
# dates
# day
# decisions
# deferred
# deficit
# del
# delegated
# delegierten
# destination
# detailed
# determination
# deutschland
# developing
# did
# din
# directive
# discharge
# disclose
# doubts
# duty
# ecb
# ecsc
# edf
# education
# eec
# effectively
# efta
# eib
# eighth
# el
# eller
# employment
# energy
# entre
# entscheidung
# equivalent
# errors
# es
# esa
# escolares
# esma
# estimates
# eu
# eur
# euratom
# euro
# europaparlamentets
# eurostat
# ex
# excise
# exemption
# extended
# ezb
# farmers
# farming
# februar
# federal
# fee
# field
# file
# financed
# financial
# fiscal
# fiscalis
# fisheries
# fiu
# foodaid
# foreseen
# forwarded
# frase
# free
# freedom
# freezing
# french
# fry
# från
# functioning
# fund
# funds
# fuq
# fusionskontrollverordnung
# gasification
# gdp
# gemeinsame
# goods
# government
# grant
# greek
# guarantee
# hard
# harmonised
# haute
# head
# heading
# headings
# health
# held
# hicp
# holding
# hungarian
# hungary
# ias
# ifrs
# implementation
# implemented
# indices
# injury
# inquiry
# inspection
# institutions
# instruments
# insurance
# integrate
# internal
# investigation
# investment
# invitro
# iraq
# ireland
# items
# iv
# ivm
# ix
# iz
# ja
# je
# jornal
# joulukuuta
# junho
# juridique
# kapitalgrundlag
# kept
# kommission
# laboratory
# laws
# legislation
# lessfavoured
# levies
# levy
# limits
# listing
# local
# london
# maintain
# marino
# markets
# material
# maximum
# meaning
# measure
# meeting
# membre
# merger
# mit
# modernization
# monaco
# monetary
# muss
# má
# második
# määruse
# nace
# namiesto
# ninth
# noncompliance
# notice
# notification
# november
# nº
# october
# octs
# olaf
# olla
# operation
# operations
# opinion
# opinions
# oraz
# organisation
# originating
# outermost
# overseas
# paid
# parlamenta
# parlamenti
# parlamento
# parlaments
# parlamentu
# parlement
# parliament
# participation
# partie
# parties
# partners
# pas
# pay
# payments
# penalties
# performance
# pericles
# persons
# pilot
# planning
# plant
# plates
# plus
# po
# policies
# policy
# pomocy
# portuguese
# position
# pour
# premium
# premiums
# preparation
# preparatory
# presence
# pricing
# principality
# procedimiento
# proceeding
# producer
# producers
# products
# professional
# programme
# programming
# projects
# proposals
# proposed
# prospectus
# protective
# protocol
# public
# punkti
# på
# rates
# recapitalisation
# received
# recipient
# recital
# recommendation
# referred
# reform
# refund
# regarding
# region
# regulated
# reinsurance
# relief
# repayable
# report
# reporting
# requested
# requirements
# resolution
# resources
# restructuring
# revenue
# risks
# rules
# said
# satisfy
# savings
# sbk
# scheme
# schemes
# schengen
# section
# sector
# securities
# seite
# series
# shall
# skladu
# social
# solvency
# sources
# south
# standards
# state
# statistical
# stedet
# stock
# strona
# structural
# structures
# supervisory
# supplied
# supplies
# supporting
# survey
# sv
# szolgáltatások
# tai
# taken
# talparlament
# tariff
# tax
# taxable
# taxation
# taxe
# taxes
# texts
# thorn
# title
# tonne
# tonnes
# trade
# transactions
# transfers
# transport
# treba
# turnover
# ue
# undertakings
# units
# uradni
# usd
# using
# utilized
# vagy
# valueadded
# van
# vat
# version
# veterinary
# vii
# vineyards
# wages
# waterway
# workshops
# xc
# xv
# xxii
# year
# yra
# zusammenschluss
# în
# ευρωπαϊκού
# κατά
# μόνο
# σημείο
# τις
# директива
# ецб
# 452 selected features from total of 227815

# %%
#check result here...

# %% [markdown]
# ### Check on test data (gold standard):

# %%
# !python ../classifier/test.py \
--filename /notebook/nas-trainings/arne/DGFISMA_doc_classification/DATA/test_data_milieu_iteration1.tsv   \
--model_path /notebook/nas-trainings/arne/DGFISMA_doc_classification/MODELS/MODEL_REMOVE_PUNCTUATION_GOOD/model.p \
--output_file /notebook/nas-trainings/arne/DGFISMA_doc_classification/MODELS/MODEL_REMOVE_PUNCTUATION_GOOD/output_test_milieu.txt
# Out:
# /miniconda/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Removing punctuation and numbers
# 117 documents - 11.891MB (test set)
# 2 categories
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        73
#            1       0.67      1.00      0.80        44
#
#    micro avg       0.81      0.81      0.81       117
#    macro avg       0.83      0.85      0.81       117
# weighted avg       0.87      0.81      0.81       117

# %%
# !python ../classifier/test.py \
--filename /notebook/nas-trainings/arne/DGFISMA_doc_classification/DATA/test_data_milieu_iteration1.tsv   \
--model_path /notebook/nas-trainings/arne/DGFISMA_doc_classification/MODELS/MODEL_REMOVE_PUNCTUATION/model.p \
--output_file /notebook/nas-trainings/arne/DGFISMA_doc_classification/MODELS/MODEL_REMOVE_PUNCTUATION/output_test_milieu.txt
# Out:
# /miniconda/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# 117 documents - 12.418MB (test set)
# 2 categories
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        73
#            1       0.69      1.00      0.81        44
#
#    micro avg       0.83      0.83      0.83       117
#    macro avg       0.84      0.86      0.83       117
# weighted avg       0.88      0.83      0.83       117

# %%
# !python ../classifier/test.py \
--filename /notebook/nas-trainings/arne/DGFISMA_doc_classification/DATA/test_data_milieu_iteration1.tsv   \
--model_path /notebook/nas-trainings/arne/DGFISMA_doc_classification/src/app/models/model.p  \
--output_file /notebook/nas-trainings/arne/DGFISMA_doc_classification/MODELS/MODEL_REMOVE_PUNCTUATION/output_test_milieu.txt
# Out:
# /miniconda/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Removing punctuation and numbers
# 117 documents - 11.891MB (test set)
# 2 categories
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.66      0.79        73
#            1       0.64      1.00      0.78        44
#
#    micro avg       0.79      0.79      0.79       117
#    macro avg       0.82      0.83      0.79       117
# weighted avg       0.86      0.79      0.79       117

# %%
test_data=[ base64.b64decode( doc ).decode().translate(str.maketrans('', '', string.punctuation+'0123456789'  )) for doc in test_data  ]
