# %%
import sys
sys.path.append( "/notebook/nas-trainings/arne/DGFISMA_doc_classification/src/classifier")
from train import train

import configparser

CONFIG = configparser.ConfigParser()
CONFIG.read( "/notebook/nas-trainings/arne/DGFISMA_doc_classification/src/classifier/train.config" )

train( CONFIG  )
# Out:
# Removing punctuation and numbers
# 12599 documents - 287.208MB (training set)
# 2 categories
#
# Using Tfidf Vectorizer.
# Using balanced class weights.
# Extracting features via sklearn.feature_selection. SelectKbest using LinearSVC.
# Selected features are:
#
# abl
# acceding
# access
# accession
# accidents
# accordingly
# accounting
# achieved
# acp
# actions
# active
# additive
# address
# adjusting
# adjustments
# administrative
# adopt
# af
# ag
# agents
# aggressive
# agreement
# agreements
# agus
# aid
# aids
# air
# aircraft
# amend
# amending
# amendments
# amlcft
# andorra
# anexo
# applicant
# applying
# approved
# arearelated
# areas
# armenia
# articles
# associated
# association
# associations
# assurance
# auditors
# authorities
# authority
# authorizing
# aviation
# avoidance
# ba
# balance
# bank
# base
# bce
# beneficiary
# besedilo
# billion
# broken
# budget
# budgetary
# burden
# bureau
# bureaux
# business
# byť
# calculating
# calculation
# calendar
# ...

# %% [markdown]
# ### Check on test data (gold standard):

# %%
# !python ../classifier/test.py \
--filename /notebook/nas-trainings/arne/DGFISMA_doc_classification/DATA/test_data_milieu_iteration1.tsv   \
--model_path /notebook/nas-trainings/arne/DGFISMA_doc_classification/MODELS/MODEL_WITH_SOLR_DATA_MILIEU/model.p \
--output_file /notebook/nas-trainings/arne/DGFISMA_doc_classification/MODELS/MODEL_REMOVE_PUNCTUATION/output_test_milieu.txt
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Removing punctuation and numbers
# 117 documents - 11.891MB (test set)
# 2 categories
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        73
#            1       0.67      1.00      0.80        44
#
#    micro avg       0.81      0.81      0.81       117
#    macro avg       0.83      0.85      0.81       117
# weighted avg       0.87      0.81      0.81       117

# %%
#to test the API:
curl -H "Content-Type: application/json" -d @example.json -X POST http://localhost:5000/classify_doc
